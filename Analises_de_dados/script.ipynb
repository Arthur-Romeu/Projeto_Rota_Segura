# %%
# !pip install -q pandas

import pandas as pd

df_nos = pd.read_csv('c:/Users/00/OneDrive/Desktop/Rota_Segura/nos.csv')

df_prioridades = pd.read_csv("C:/Users/00/OneDrive/Desktop/Rota_Segura/prioridades.csv")

df_trechos = pd.read_csv("C:/Users/00/OneDrive/Desktop/Rota_Segura/trechos.csv")
# Out:
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df_nos
# Out:
#                      id                        nome        lat        lng
# 0   cem_03_de_ceilandia         CEM 03 DE CEILÂNDIA -15.827009 -48.098270
# 1              eqnm_3_5                    EQNM 3/5 -15.826121 -48.101898
# 2                 feira  Feira Central de Ceilândia -15.816945 -48.104074
# 3             guariroba             Metrô Guariroba -15.830668 -48.107097
# 4                   hrc     Hospital Regional (HRC) -15.815758 -48.096917
# 5           metroCentro      Metrô Ceilândia Centro -15.821791 -48.112413
# 6              pracaCid            Praça do Cidadão -15.812866 -48.102518
# 7             pracaTrab        Praça do Trabalhador -15.823125 -48.101253
# 8      qnm_3_conjunto_i            QNM 3 CONJUNTO I -15.822272 -48.104004
# 9                 qnm_5                       QNM 5 -15.827982 -48.100161
# 10         qnm_5_conj_o                QNM 5 CONJ O -15.825488 -48.100140
# 11     qnm_5_conjunto_i            QNM 5 CONJUNTO I -15.827330 -48.101173
# ...

# %%
df_trechos
# Out:
#      id                       via                   de              para  \
# 0   t01     Acesso Terminal–Metrô             terminal       metroCentro
# 1   t02          Av. Hélio Prates             terminal             feira
# 2   t03          Av. Hélio Prates                feira             qnm17
# 3   t04           Via interna QNM                feira          pracaCid
# 4   t05                    Via N1             pracaCid              sesc
# 5   t06        Travessa QNM 13/15             pracaCid             qnm13
# 6   t07                   Via QNM                qnm17             qnm13
# 7   t08                 Via Leste             terminal               hrc
# 8   t09           Via interna QNN                 sesc               hrc
# 9   t10              Via do Metrô          metroCentro         pracaTrab
# 10  t11              Via do Metrô            pracaTrab         guariroba
# 11  t12                Via QNN 24                qnn24         pracaTrab
# ...

# %%
df_prioridades
# Out:
#      id                       via  nivel  sinal_policiamento  \
# 0   t06        Travessa QNM 13/15      1                   0
# 1   t09           Via interna QNN      1                   0
# 2   t12                Via QNN 24      1                   0
# 3   t16        Via de ligação Sul      1                   0
# 4   t19            METROCEIL-QNN4      1                   0
# 5   t26         QNM 5 CJ  - QNM 5      1                   0
# 6   t27               QNM 5-CEM03      1                   0
# 7   t03          Av. Hélio Prates      2                   0
# 8   t04           Via interna QNM      2                   0
# 9   t07                   Via QNM      2                   0
# 10  t08                 Via Leste      2                   0
# 11  t11              Via do Metrô      2                   0
# 12  t13                   Via QNN      2                   0
# 13  t14         Via QNN–Guariroba      2                   0
# ...
